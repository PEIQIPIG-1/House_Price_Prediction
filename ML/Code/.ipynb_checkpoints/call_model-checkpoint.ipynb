# %%
# Load model and scaler
import joblib

model = joblib.load('../model/xgb_std.pickle')
scaler = joblib.load('../scaler/scaler_std.pickle')

# %%
#Import existing data
import pandas as pd

existing_data = pd.read_csv("../data/clean_data.csv")

# %%
existing_data
# Out:
#       price(1000$)  bedrooms  bathrooms  sqm_living   sqm_lot  floors  \
# 0          313.000       3.0       1.50      124.62   735.816     1.5
# 1         2384.000       5.0       2.50      339.45   841.650     2.0
# 2          342.000       3.0       2.00      179.49  1111.071     1.0
# 3          420.000       3.0       2.25      186.00   746.790     1.0
# 4          550.000       4.0       2.50      180.42   976.500     1.0
# ...            ...       ...        ...         ...       ...     ...
# 4093       308.166       3.0       1.75      140.43   591.480     1.0
# 4094       534.333       3.0       2.50      135.78   704.289     2.0
# 4095       416.904       3.0       2.50      279.93   652.302     2.0
# 4096       203.400       4.0       2.00      194.37   616.590     1.0
# 4097       220.600       3.0       2.50      138.57   753.486     2.0
#
#       waterfront  view  condition  sqm_above  sqm_basement  yr_built  \
# 0              0     0          3     124.62          0.00        59
# 1              0     4          5     313.41         26.04        93
# 2              0     0          4     179.49          0.00        48
# 3              0     0          4      93.00         93.00        51
# 4              0     0          4     106.02         74.40        38
# ...          ...   ...        ...        ...           ...       ...
# 4093           0     0          4     140.43          0.00        60
# 4094           0     0          3     135.78          0.00        31
# 4095           0     0          3     279.93          0.00         5
# 4096           0     0          3      99.51         94.86        40
# 4097           0     0          4     138.57          0.00        24
#
#       yr_renovated                                      Address   Latitude  \
# 0                9  18810 Densmore Ave N Shoreline WA 98133 USA  47.765784
# 1               93         709 W Blaine St Seattle WA 98119 USA  47.634528
# 2               48   26206-26214 143rd Ave SE Kent WA 98042 USA  47.367389
# 3               51        857 170th Pl NE Bellevue WA 98008 USA  47.618727
# 4               22       9105 170th Ave NE Redmond WA 98052 USA  47.683072
# ...            ...                                          ...        ...
# 4093            35          501 N 143rd St Seattle WA 98133 USA  47.732048
# 4094             5       14855 SE 10th Pl Bellevue WA 98007 USA  47.601195
# 4095             5         759 Ilwaco Pl NE Renton WA 98059 USA  47.494972
# 4096            40       5148 S Creston St Seattle WA 98178 USA  47.507109
# 4097            24     18717 SE 258th St Covington WA 98042 USA  47.371119
#
#        Longitude  Month  living_ratio
# 0    -122.338860      5      0.169363
# 1    -122.366896      5      0.403315
# 2    -122.150525      5      0.161547
# 3    -122.113859      5      0.249066
# 4    -122.113971      5      0.184762
# ...          ...    ...           ...
# 4093 -122.352864      7      0.237421
# 4094 -122.141083      7      0.192790
# 4095 -122.149350      7      0.429142
# 4096 -122.267937      7      0.315234
# 4097 -122.092092      7      0.183905
#
# [4098 rows x 18 columns]

# %%
existing_data.drop(['Address', 'price(1000$)'], axis=1, inplace=True)
existing_data
# Out:
#       bedrooms  bathrooms  sqm_living   sqm_lot  floors  waterfront  view  \
# 0          3.0       1.50      124.62   735.816     1.5           0     0
# 1          5.0       2.50      339.45   841.650     2.0           0     4
# 2          3.0       2.00      179.49  1111.071     1.0           0     0
# 3          3.0       2.25      186.00   746.790     1.0           0     0
# 4          4.0       2.50      180.42   976.500     1.0           0     0
# ...        ...        ...         ...       ...     ...         ...   ...
# 4093       3.0       1.75      140.43   591.480     1.0           0     0
# 4094       3.0       2.50      135.78   704.289     2.0           0     0
# 4095       3.0       2.50      279.93   652.302     2.0           0     0
# 4096       4.0       2.00      194.37   616.590     1.0           0     0
# 4097       3.0       2.50      138.57   753.486     2.0           0     0
#
#       condition  sqm_above  sqm_basement  yr_built  yr_renovated   Latitude  \
# 0             3     124.62          0.00        59             9  47.765784
# 1             5     313.41         26.04        93            93  47.634528
# 2             4     179.49          0.00        48            48  47.367389
# 3             4      93.00         93.00        51            51  47.618727
# 4             4     106.02         74.40        38            22  47.683072
# ...         ...        ...           ...       ...           ...        ...
# 4093          4     140.43          0.00        60            35  47.732048
# 4094          3     135.78          0.00        31             5  47.601195
# 4095          3     279.93          0.00         5             5  47.494972
# 4096          3      99.51         94.86        40            40  47.507109
# 4097          4     138.57          0.00        24            24  47.371119
#
#        Longitude  Month  living_ratio
# 0    -122.338860      5      0.169363
# 1    -122.366896      5      0.403315
# 2    -122.150525      5      0.161547
# 3    -122.113859      5      0.249066
# 4    -122.113971      5      0.184762
# ...          ...    ...           ...
# 4093 -122.352864      7      0.237421
# 4094 -122.141083      7      0.192790
# 4095 -122.149350      7      0.429142
# 4096 -122.267937      7      0.315234
# 4097 -122.092092      7      0.183905
#
# [4098 rows x 16 columns]

# %%
original_data = existing_data.iloc[4000].copy()
history_features = pd.DataFrame(columns=existing_data.columns)
predict_features = pd.DataFrame(columns=existing_data.columns)

# %%
for i in range(6):
    temp = original_data.copy()
    temp['Month'] = i + 5
    history_features = pd.concat([history_features, pd.DataFrame([temp])], ignore_index=True)
history_features
# Out:
#    bedrooms  bathrooms  sqm_living  sqm_lot  floors  waterfront  view  \
# 0       4.0       2.25      277.14  748.743     1.5         0.0   2.0
# 1       4.0       2.25      277.14  748.743     1.5         0.0   2.0
# 2       4.0       2.25      277.14  748.743     1.5         0.0   2.0
#
#    condition  sqm_above  sqm_basement  yr_built  yr_renovated   Latitude  \
# 0        4.0     187.86         89.28      79.0          79.0  47.642472
# 1        4.0     187.86         89.28      79.0          79.0  47.642472
# 2        4.0     187.86         89.28      79.0          79.0  47.642472
#
#     Longitude  Month  living_ratio
# 0 -122.409179    5.0       0.37014
# 1 -122.409179    6.0       0.37014
# 2 -122.409179    7.0       0.37014

# %%
for i in range(3):
    temp = original_data.copy()
    temp['Month'] = i + 8
    predict_features = pd.concat([predict_features, pd.DataFrame([temp])], ignore_index=True)
predict_features
# Out:
#    bedrooms  bathrooms  sqm_living  sqm_lot  floors  waterfront  view  \
# 0       4.0       2.25      277.14  748.743     1.5         0.0   2.0
# 1       4.0       2.25      277.14  748.743     1.5         0.0   2.0
# 2       4.0       2.25      277.14  748.743     1.5         0.0   2.0
#
#    condition  sqm_above  sqm_basement  yr_built  yr_renovated   Latitude  \
# 0        4.0     187.86         89.28      79.0          79.0  47.642472
# 1        4.0     187.86         89.28      79.0          79.0  47.642472
# 2        4.0     187.86         89.28      79.0          79.0  47.642472
#
#     Longitude  Month  living_ratio
# 0 -122.409179    8.0       0.37014
# 1 -122.409179    9.0       0.37014
# 2 -122.409179   10.0       0.37014

# %%
history_features = scaler.transform(history_features)
predict_features = scaler.transform(predict_features)

# %%
history_prices = model.predict(history_features)
history_prices
# Out:
# array([577.7593, 570.5319, 565.9272], dtype=float32)

# %%
import numpy as np
predicted_prices = model.predict(predict_features)

predicted_prices = np.insert(predicted_prices, 0, history_prices[-1])
predicted_prices
# Out:
# array([565.9272, 565.9272, 565.9272, 565.9272], dtype=float32)

# %%
import matplotlib.pyplot as plt

# features = ['bedrooms', 'bathrooms', 'sqm_living', 'sqm_lot', 'floors', 'waterfront','view', 'condition', 
#               'sqm_above', 	'sqm_basement', 'yr_built', 'yr_renovated', 'living_ratio']



months = ['May','June', 'July', 'August', 'Sepetember', 'October']  
 

plt.figure(figsize=(10, 6))

plt.plot(months[:3], history_prices, marker='o', label='Historical Prices', color='blue')


plt.plot(months[2:], predicted_prices, marker='o', linestyle='--', label='Predicted Prices', color='red')


plt.title('House Price Prediction')
plt.xlabel('Month')
plt.ylabel('Price(1000$)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
