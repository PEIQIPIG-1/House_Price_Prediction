# %%
# This file is aiming at processing data.
# As the data processing process needs to call google api, it is not convenient to re-run the data processing code every time the model is tuned
# Don't need to run this code if you just want to model
# The procecssed data will be exported as Processed_data.csv file
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../data/data.csv")

# %%
data
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
from decimal import Decimal
# Convert house price to integer
data['price'] = data['price'].astype(float).astype(int)
data.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
# Combine to full address for coordinate translation
data['Address'] = data['street'].str.cat([data['city'],data['statezip'], data['country']],sep=' ')
data.head()
# Out:
#                   date    price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
#Creating Latitude and Longitude Attributes
data['Latitude'] = 0
data['Longitude'] = 0
data
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2384000       5.0       2.50         3650
# 2     2014-05-02 00:00:00   342000       3.0       2.00         1930
# 3     2014-05-02 00:00:00   420000       3.0       2.25         2000
# 4     2014-05-02 00:00:00   550000       4.0       2.50         1940
# ...                   ...      ...       ...        ...          ...
# 4595  2014-07-09 00:00:00   308166       3.0       1.75         1510
# 4596  2014-07-09 00:00:00   534333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00   416904       3.0       2.50         3010
# 4598  2014-07-10 00:00:00   203400       4.0       2.00         2090
# 4599  2014-07-10 00:00:00   220600       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# ...

# %%
#Converting Addresses to Latitude and Longitude with Google Api
import googlemaps
from datetime import datetime

gmaps = googlemaps.Client(key='AIzaSyDRFAJluyKha3xJ0eDffsvv3nRQtdFuHHU')
rows = data.shape[0]

for i in range(rows):
    geocode_result = gmaps.geocode(data['Address'][i])
    data['Latitude'][i] = geocode_result[0]['geometry']['location']['lat']
    data['Longitude'][i] = geocode_result[0]['geometry']['location']['lng']
data
# Out:
#                      date    price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00   313000       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2384000       5.0       2.50         3650
# 2     2014-05-02 00:00:00   342000       3.0       2.00         1930
# 3     2014-05-02 00:00:00   420000       3.0       2.25         2000
# 4     2014-05-02 00:00:00   550000       4.0       2.50         1940
# ...                   ...      ...       ...        ...          ...
# 4595  2014-07-09 00:00:00   308166       3.0       1.75         1510
# 4596  2014-07-09 00:00:00   534333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00   416904       3.0       2.50         3010
# 4598  2014-07-10 00:00:00   203400       4.0       2.00         2090
# 4599  2014-07-10 00:00:00   220600       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  ...  sqft_basement  \
# ...

# %%
#Extract year and month from date as new attributes
data['date'] = pd.to_datetime(data['date'], format='%Y-%m-%d %H:%M:%S')
data['Year'] = data['date'].dt.year
data['Month'] = data['date'].dt.month
data.head()
# Out:
#         date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-05-02   313000       3.0       1.50         1340      7912     1.5
# 1 2014-05-02  2384000       5.0       2.50         3650      9050     2.0
# 2 2014-05-02   342000       3.0       2.00         1930     11947     1.0
# 3 2014-05-02   420000       3.0       2.25         2000      8030     1.0
# 4 2014-05-02   550000       4.0       2.50         1940     10500     1.0
#
#    waterfront  view  condition  ...  yr_renovated                    street  \
# 0           0     0          3  ...          2005      18810 Densmore Ave N
# 1           0     4          5  ...             0           709 W Blaine St
# 2           0     0          4  ...             0  26206-26214 143rd Ave SE
# 3           0     0          4  ...             0           857 170th Pl NE
# 4           0     0          4  ...          1992         9105 170th Ave NE
#
# ...

# %%
#data back up
data_backup = data.copy()
data_backup
# Out:
#            date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0    2014-05-02   313000       3.0       1.50         1340      7912     1.5
# 1    2014-05-02  2384000       5.0       2.50         3650      9050     2.0
# 2    2014-05-02   342000       3.0       2.00         1930     11947     1.0
# 3    2014-05-02   420000       3.0       2.25         2000      8030     1.0
# 4    2014-05-02   550000       4.0       2.50         1940     10500     1.0
# ...         ...      ...       ...        ...          ...       ...     ...
# 4595 2014-07-09   308166       3.0       1.75         1510      6360     1.0
# 4596 2014-07-09   534333       3.0       2.50         1460      7573     2.0
# 4597 2014-07-09   416904       3.0       2.50         3010      7014     2.0
# 4598 2014-07-10   203400       4.0       2.00         2090      6630     1.0
# 4599 2014-07-10   220600       3.0       2.50         1490      8102     2.0
#
# ...

# %%
#Export as csv file
data.to_csv('Processed_data.csv',index=False,header=True)
pd.read_csv('Processed_data.csv')
# Out:
#             date    price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     2014-05-02   313000       3.0       1.50         1340      7912     1.5
# 1     2014-05-02  2384000       5.0       2.50         3650      9050     2.0
# 2     2014-05-02   342000       3.0       2.00         1930     11947     1.0
# 3     2014-05-02   420000       3.0       2.25         2000      8030     1.0
# 4     2014-05-02   550000       4.0       2.50         1940     10500     1.0
# ...          ...      ...       ...        ...          ...       ...     ...
# 4595  2014-07-09   308166       3.0       1.75         1510      6360     1.0
# 4596  2014-07-09   534333       3.0       2.50         1460      7573     2.0
# 4597  2014-07-09   416904       3.0       2.50         3010      7014     2.0
# 4598  2014-07-10   203400       4.0       2.00         2090      6630     1.0
# 4599  2014-07-10   220600       3.0       2.50         1490      8102     2.0
#
# ...
